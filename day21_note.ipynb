# %% [markdown]
# ### welcome to day 21/30 days python
#
# - Matplotlib
# - line plot
# - bar chart
# - pie chart
# - area chart
# - scatter plot
# - histogram
# - customizations (labels, colors, legends)

# %%
#importing matplotlib
import matplotlib.pyplot as plt
import numpy as np

# this is to show the chart in jpnb
# %matplotlib inline

# %%
x = np.linspace(0, 10, 100)  # Generate 100 points from 0 to 10
y = np.sin(x)  # Sine wave

# %%
y2 = np.cos(x)
y2
# Out:
# array([ 1.        ,  0.99490282,  0.97966323,  0.95443659,  0.91948007,
#         0.87515004,  0.8218984 ,  0.76026803,  0.69088721,  0.61446323,
#         0.53177518,  0.44366602,  0.35103397,  0.25482335,  0.15601496,
#         0.0556161 , -0.04534973, -0.14585325, -0.24486989, -0.34139023,
#        -0.43443032, -0.52304166, -0.60632092, -0.68341913, -0.75355031,
#        -0.81599952, -0.87013012, -0.91539031, -0.95131866, -0.97754893,
#        -0.9938137 , -0.99994717, -0.9958868 , -0.981674  , -0.95745366,
#        -0.92347268, -0.88007748, -0.82771044, -0.76690542, -0.69828229,
#        -0.6225406 , -0.54045251, -0.45285485, -0.36064061, -0.26474988,
#        -0.16616018, -0.06587659,  0.03507857,  0.13567613,  0.23489055,
#         0.33171042,  0.4251487 ,  0.51425287,  0.59811455,  0.67587883,
#         0.74675295,  0.8100144 ,  0.86501827,  0.91120382,  0.94810022,
#         0.97533134,  0.99261957,  0.99978867,  0.99676556,  0.98358105,
#         0.96036956,  0.9273677 ,  0.88491192,  0.83343502,  0.77346177,
#         0.70560358,  0.63055219,  0.54907273,  0.46199582,  0.37020915,
#         0.27464844,  0.17628785,  0.07613012, -0.0248037 , -0.12548467,
#        -0.2248864 , -0.32199555, -0.41582217, -0.50540974, -0.58984498,
#        -0.66826712, -0.7398767 , -0.8039437 , -0.859815  , -0.90692104,
#        -0.94478159, -0.97301068, -0.99132055, -0.99952453, -0.99753899,
#        -0.98538417, -0.96318398, -0.93116473, -0.88965286, -0.83907153])

# %%
plt.plot(x, y, color='red')
plt.title("Sine Wave Trending Line", fontsize=14)
plt.ylabel("Y Axis")
plt.xlabel("X Axis")
plt.show()

# %% [markdown]
# Exercise 1: Create a cosine wave plot using np.cos(). Customize the line with a dashed style.

# %%
plt.figure(figsize=(8, 5))
plt.plot(x, y2, color='blue', label="cos wave line")
plt.plot(x, y, color='red', label="sine wave line")
plt.title("Cos & Sine Wave Trending Lines", fontsize=14)
plt.ylabel("Y Axis")
plt.xlabel("X Axis")
plt.legend()
plt.savefig('chart1.png')
plt.show()

# %% [markdown]
# **Bar Chart**

# %%
categories = ['A', 'B', 'C', 'D']
values = [5, 7, 3, 8]

# %%
colors = ('blue', 'red', 'green', 'purple')
plt.bar(categories, values, width=0.6, color=colors, alpha=0.7)
plt.title("Sales Bar Chart")
plt.xlabel("Categories")
plt.ylabel("Sales in Millions $")
# plt.grid(axis='y', linestyle='--')
plt.show()

# %%
colors = ('blue', 'red', 'green', 'purple')
plt.barh(categories, values, color=colors, alpha=0.5)
plt.title("Sales Bar Chart")
plt.xlabel("Categories")
plt.ylabel("Sales in Millions $")
# plt.grid(axis='y', linestyle='--')
plt.show()

# %% [markdown]
# Exercise 2: Plot a horizontal bar chart using plt.barh(). Try changing the bar color to green.

# %% [markdown]
# **Histogram**
# A histogram helps to visualize the distribution of data.

# %%
data = np.random.randn(1000)
data
# Out:
# array([ 1.27012239e-01, -1.24944372e+00,  1.94511561e+00, -1.53336458e-01,
#        -9.06987225e-01, -8.17354155e-01, -4.83122679e-01, -5.69828348e-01,
#        -2.09159967e+00,  1.26374053e+00, -1.54833400e-02, -2.73764456e-02,
#         8.17873512e-01, -1.05460447e+00, -7.58327121e-01,  4.57415649e-01,
#        -6.43780508e-02,  3.44902335e-01, -8.00873354e-02, -2.41380132e-01,
#         1.43351549e+00,  1.06579371e+00, -2.49875914e+00,  1.48032856e+00,
#         2.15872852e+00,  1.23177838e+00, -2.14324483e-01, -6.89194210e-01,
#         7.27833114e-01, -6.19069360e-01,  3.56159830e-01, -2.18808743e-02,
#         1.21805044e+00, -3.89458024e-01, -4.42802345e-01,  3.78226615e-01,
#         1.93383980e+00,  8.09708059e-02, -4.16456364e-01,  8.57503252e-01,
#         7.18128280e-01, -9.51471751e-01, -5.36160100e-01,  1.09652886e+00,
#         4.28012841e-01, -2.46969887e+00,  4.81979139e-01,  9.26456359e-01,
#        -8.37581392e-01,  6.77186066e-01,  1.87231912e+00,  3.96373940e-01,
#        -6.25616295e-01, -5.22461480e-01,  1.30338998e-02,  3.77769592e-01,
#         6.28245997e-02,  5.01596365e-01, -1.46945393e-01,  1.80622974e-01,
#         9.64810582e-01, -1.06483115e+00,  1.08711800e-01,  1.05763647e-01,
#         9.20666716e-01, -2.26722456e-01,  6.53048311e-01,  1.10268747e+00,
#        -1.84980294e+00,  1.16863124e+00, -9.85381797e-01, -1.09394041e+00,
#        -2.87945689e+00, -8.03177665e-01, -4.85694465e-03, -3.83323306e-01,
#        -4.62526860e-01, -1.11249735e+00,  8.67229499e-01,  9.58413836e-01,
#         4.18118522e-01, -1.88652805e+00,  2.27334516e+00,  1.46974650e-01,
#         5.39609202e-01, -1.49829564e+00, -1.14434475e-02,  4.13354088e-01,
#        -1.40898554e-01,  8.72161859e-01,  1.30034515e+00, -1.34352376e+00,
#         8.50120582e-01,  3.94339951e-01, -4.69599467e-03, -1.57081198e+00,
#         1.47984878e+00,  3.96774281e-01, -1.78325106e+00, -2.43134460e-01,
#         3.27223386e-01,  5.06575302e-01, -1.27604794e-01,  3.41590806e-01,
#         2.11888621e+00,  1.54653676e+00, -9.49519045e-01, -5.96897332e-01,
#        -1.11204000e-01, -1.74906943e+00, -1.34140350e+00, -1.62169462e+00,
#        -1.14771997e+00,  1.38960283e+00, -8.55240519e-01, -1.02706176e+00,
#        -8.28509148e-02, -3.73165182e-01,  1.50972580e+00,  1.64050339e+00,
#         5.99783856e-01,  1.13354677e+00, -1.27722047e+00, -1.54877982e+00,
#         1.24632689e+00, -1.26811498e-01,  7.49302417e-01, -7.17287950e-01,
#         1.65698847e+00, -1.54041867e+00, -1.38558509e+00,  1.44431158e+00,
#        -2.60984179e+00,  3.78568868e-01, -1.07325996e-01, -7.35951919e-01,
#        -1.99939849e-01, -8.47523493e-01,  1.54225595e+00,  1.80449709e+00,
#        -6.85737587e-01,  2.75524877e-01, -1.32507647e+00,  1.07305216e+00,
#         1.04700917e+00, -2.95262233e-01,  1.68850584e-02, -9.37654495e-02,
#        -1.61845783e+00,  1.54600415e+00, -7.66953239e-01, -7.60149272e-01,
#        -1.50419854e-01,  9.95548585e-01, -5.91303215e-01, -1.95218522e+00,
#        -8.86998061e-01,  4.24140419e-01,  2.18975029e+00, -1.25991997e+00,
#        -1.29650177e+00, -1.51259550e+00, -1.63672499e+00,  1.20569146e+00,
#         1.49468858e+00,  1.77755894e-01, -4.67712772e-01,  1.79114379e+00])

# %%
plt.hist(data, bins=20, color='blue' , alpha=0.5)
plt.title("Sample Data Distribution")
plt.xlabel("X label")
plt.ylabel("Y Label")
plt.show()

# %% [markdown]
# Exercise 3: Create a histogram with 50 bins. Use a red color for the bars and 50% transparency (alpha=0.5)

# %%
data = np.random.randn(1000)

# %% [markdown]
# **Exercise Task**

# %% [markdown]
# Exercise 1: Sales Trend Analysis
# Objective: Analyze monthly sales data to identify trends.
#
# Customization:
# Add title, axis labels, and markers, show legend

# %%
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
sales = [4500, 4800, 5000, 4700, 6300, 5300, 4600, 4800, 6000, 5200, 6100, 5400]

# %%
plt.figure(figsize=(10, 5))
plt.plot(months, sales, color='green', marker='o', label='Trend Lines')
plt.title("Monthly Sales Trends")
plt.xlabel("Months")
plt.ylabel("Sales in $")
plt.legend()
plt.show()

# %% [markdown]
# Exercise 2: Category-Wise Sales Comparison
#
# Objective: Compare product category performance using a bar chart.
#
# Task: Create a bar chart comparing category sales.
# Customization:
# Use different colors for each bar.

# %%
categories = ['Electronics', 'Furniture', 'Clothing', 'Books']
sales = [10000, 7000, 8000, 5000]

# %%
plt.bar(categories, values, width=0.6, color=colors, alpha=0.7)
plt.title("Sales Bar Chart")
plt.xlabel("Categories")
plt.ylabel("Sales in Millions $")
# plt.grid(axis='y', linestyle='--')
plt.savefig('bar.png')
plt.show()

# %% [markdown]
# Exercise 3: Customer Age Distribution
#
# Objective: Visualize the distribution of customer ages using a histogram.
#
# Task: Create a histogram of ages with 10 bins.
# Customization:
# Add gridlines for better visualization.
# Customize color and transparency.

# %%
#random age
ages = np.random.randint(18, 65, 500)  # 500 random ages between 18 and 65
ages
# Out:
# array([64, 32, 23, 61, 37, 31, 19, 26, 54, 37, 43, 46, 18, 52, 23, 54, 22,
#        50, 21, 21, 56, 57, 34, 54])

# %%
plt.hist(ages, bins=10, color='red' , alpha=0.7)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Age bins")
plt.show()

# %% [markdown]
# Exercise 4: Regional Sales Performance (Pie Chart)
#
# Objective: Visualize the percentage contribution of each region to total sales.
#
# Task: Create a pie chart showing sales contribution by region.
# Customization:
# Explode the region with the highest sales.
# Add percentage labels on each slice.

# %%
regions = ['North', 'South', 'East', 'West']
sales = [3000, 4000, 2200, 1500]

# %%
colors = ('red', 'skyblue', 'green', 'purple')
explodes = (0, 0.1, 0, 0)
plt.pie(sales, labels=regions, autopct='%1.2f%%', colors=colors, explode=explodes, shadow=True)
plt.savefig('pie.png')

# %% [markdown]
# Exercise 5: Sales Forecast Visualization (Shaded Area Plot)
#
# Objective: Visualize historical sales along with forecasted values using an area plot.
#
# Task: Create an area plot showing actual vs. forecasted sales.
# Customization:
# Use different colors for actual and forecasted values.
# Add hatching patterns for the forecasted area.

# %%
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun']
sales = [5000, 5200, 5400, 5300, 5500, 5700]
forecast = [5800, 5900, 6000, 6100, 6200, 6300]

# %%
plt.figure(figsize=(10,6))

plt.fill_between(months, forecast, label='Forcasting Sales', color='lightgreen', alpha=0.7, hatch='/')
plt.fill_between(months, sales, label='Actual Sales', color='skyblue', alpha=0.5)

plt.title("Actual vs Forcasted sales in $")
plt.ylabel("In Millions $")
plt.xlabel("Months")
plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.legend(loc='upper right')

plt.show()

# %% [markdown]
# Final Task: Correlation between Sales and Advertisement Spend
#
# Objective: Explore the relationship between sales and advertising spend using a scatter plot.
#
# Task: Create a scatter plot of sales vs. ad spend.
# Customization:
# Add a trendline.
# Customize marker size and color based on ad spend.

# %%
ad_spend = [1000, 1500, 1800, 2000, 2300, 2500, 3000, 3200]
sales = [4000, 4500, 5000, 5200, 5800, 6000, 6400, 7000]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data: Advertisement Spend and Sales
ad_spend = [1000, 1500, 1800, 2000, 2300, 2500, 3000, 3200]
sales = [4000, 4500, 5000, 5200, 5800, 6000, 6400, 7000]

# Create the scatter plot
plt.figure(figsize=(8, 6))
sc = plt.scatter(ad_spend, sales, 
                 c=ad_spend, cmap='cool',  # Color based on ad spend
                 s=[spend / 10 for spend in ad_spend],  # Marker size based on ad spend
                 alpha=0.7, edgecolor='black')

# Add a trendline
z = np.polyfit(ad_spend, sales, 1)  # Linear regression
p = np.poly1d(z)
plt.plot(ad_spend, p(ad_spend), linestyle='--', color='red', label='Trendline')

# Customize the plot
plt.title('Sales vs Advertisement Spend', fontsize=16)
plt.xlabel('Advertisement Spend ($)', fontsize=12)
plt.ylabel('Sales ($)', fontsize=12)
plt.colorbar(sc, label='Ad Spend')  # Add color legend
plt.legend()

# Display the plot
plt.savefig('test1.png')
plt.show()
